# %% [markdown]
# A lo largo de esta evaluación tendrás que crear una clase llamada TiendaOnline que cumpla los siguientes requisitos:

# %% [markdown]
# La clase TiendaOnline debe tener los siguientes atributos:
#  - inventario (lista de diccionarios): Un atributo para almacenar los productos en el inventario. Cada producto debe ser representado como un diccionario con las siguientes claves: 'nombre', 'precio', y 'cantidad'. Al principio deberá ser una lista vacía.
#  - ventas_totales
#  (float): Un atributo para llevar un registro de las ventas totales de la tienda.
# Inicializado con valor 0.

# %%
class TiendaOnline: #definimos la clase 
    def __init__(self, nombre): #arrancamos el constructor 
        self.nombre = nombre 
        self.inventario = [] #añado plantilla de lista vacia #'nombre', 'precio', y 'cantidad'
        self.ventas_totales = 0.0 #empezamos con 0 ventas totales, con este formato porque es un float

    def agregar_producto(self, nombre, precio, cantidad):
        nuevo_producto = {"nombre": nombre, "precio": precio, "cantidad": cantidad}
        for producto in self.inventario:
            if producto["nombre"] == nombre: 
                producto["cantidad"] += cantidad
                return
        nuevo_producto not in self.inventario
        self.inventario.append(nuevo_producto)
        print(f"Se ha añadido el producto {nombre} al inventario y hay un total de {cantidad}")

    def ver_inventario(self):
        print("El inventario es el siguiente:")
        for p in self.inventario:
            print(f"Nombre: {p['nombre']}, Precio: {p['precio']}€, Cantidad: {p['cantidad']}")

    def buscar_producto(self, nombre): 
        for b in self.inventario:
            if b['nombre'] == nombre:
                print(f"Nombre: {b['nombre']}, Precio: {b['precio']}€, Cantidad: {b['cantidad']}")
            else:
                print("El producto indicado no está en el inventario")
                return

# %% [markdown]
# La clase TiendaOnline debe tener los siguientes métodos:
#  - agregar_producto(self, nombre, precio, cantidad): Este método agrega un producto al inventario o actualiza su cantidad si ya existe. Debe recibir el nombre, precio y cantidad del producto como parámetros
#         *Itera a través del inventario y compara los nombres de los productos con el nombre
# proporcionado.
#         *Si el producto ya existe, actualiza la cantidad.
#         *Si no existe, agrega un nuevo producto al inventario.

# %%
def agregar_producto(self, nombre, precio, cantidad):
        nuevo_producto = {"nombre": nombre, "precio": precio, "cantidad": cantidad}
        for producto in self.inventario:
            if producto["nombre"] == nombre: 
                producto["cantidad"] += cantidad
                return
        nuevo_producto not in self.inventario
        self.inventario.append(nuevo_producto)
        print(f"Se ha añadido el producto {nombre} al inventario y hay un total de {cantidad}")

# %%
glowy = TiendaOnline("mi tienda")

# %%
glowy.agregar_producto("Colorete", 25, 4)
# Out:
# Se ha añadido el producto Colorete al inventario y hay un total de 4

# %%
glowy.agregar_producto("Iluminador", 30, 5)
# Out:
# Se ha añadido el producto Iluminador al inventario y hay un total de 5

# %%
glowy.agregar_producto("Iluminador", 30, 5)

# %%
glowy.agregar_producto("Máscara de pestañas", 15, 25)
# Out:
# Se ha añadido el producto Máscara de pestañas al inventario y hay un total de 25

# %%
glowy.agregar_producto("Máscara de pestañas", 15, 25)

# %%
glowy.__dict__
# Out:
# {'nombre': 'mi tienda',
#  'inventario': [{'nombre': 'Colorete', 'precio': 25, 'cantidad': 4},
#   {'nombre': 'Iluminador', 'precio': 30, 'cantidad': 10},
#   {'nombre': 'Máscara de pestañas', 'precio': 15, 'cantidad': 50}],
#  'ventas_totales': 0.0}

# %% [markdown]
# -  ver_inventario(self): Muestra el inventario de productos con sus detalles
#     *Utiliza un bucle for para recorrer el inventario
#     *Imprime los detalles (nombre, precio, cantidad) de cada producto.

# %%
def ver_inventario(self):
    inventario = {"nombre": nombre, "precio": precio, "cantidad": cantidad}
    for key,value in self.inventario:
        print("El inventario es el siguiente:")
        print(inventario)
        return

# %%
glowy.ver_inventario()
# Out:
# El inventario es el siguiente:
# Nombre: Colorete, Precio: 25€, Cantidad: 4
# Nombre: Iluminador, Precio: 30€, Cantidad: 10
# Nombre: Máscara de pestañas, Precio: 15€, Cantidad: 50

# %%
glowy.agregar_producto("Gloss", 10, 25)
# Out:
# Se ha añadido el producto Gloss al inventario y hay un total de 25

# %%
glowy.__dict__
# Out:
# {'nombre': 'mi tienda',
#  'inventario': [{'nombre': 'Colorete', 'precio': 25, 'cantidad': 4},
#   {'nombre': 'Iluminador', 'precio': 30, 'cantidad': 10},
#   {'nombre': 'Máscara de pestañas', 'precio': 15, 'cantidad': 50},
#   {'nombre': 'Gloss', 'precio': 10, 'cantidad': 25}],
#  'ventas_totales': 0.0}

# %%
glowy.ver_inventario()
# Out:
# El inventario es el siguiente:
# Nombre: Colorete, Precio: 25€, Cantidad: 4
# Nombre: Iluminador, Precio: 30€, Cantidad: 10
# Nombre: Máscara de pestañas, Precio: 15€, Cantidad: 50
# Nombre: Gloss, Precio: 10€, Cantidad: 25

# %%
glowy.buscar_producto("Rímel")
# Out:
# El producto indicado no está en el inventario

# %% [markdown]
# - buscar_producto(self, nombre): Busca un producto en el inventario por nombre y muestra sus detalles si se encuentra. Debe recibir el nombre del producto como parámetro.
#     *Utiliza un bucle for para recorrer el inventario.
#     *Compara los nombres de los productos con el nombre proporcionado.
#     *Si se encuentra el producto, imprime sus detalles

# %%
def buscar_producto(self, nombre): 
        for b in self.inventario:
            if b['nombre'] == nombre:
                print(f"Nombre: {b['nombre']}, Precio: {b['precio']}€, Cantidad: {b['cantidad']}")
            else:
                print("El producto indicado no está en el inventario")
                return

# %% [markdown]
# - actualizar_stock(self, nombre, cantidad): Actualiza el stock de un producto en el inventario. Debe recibir el nombre del producto y la cantidad a agregar o quitar como parámetros.
#     *Utiliza un bucle for para recorrer el inventario.
#     *Busca el producto por nombre.
#     *Actualiza la cantidad según la entrada del usuario.
#     *Si el producto no esta en el inventario muestra un mensaje indicándolo.

# %%
def actualizar_stock(self, nombre, cantidad):
    for nuevo_producto in self.inventario:
        for key,value in nuevo_producto.items():
            nuevo_producto.append(f"{key["nombre"].capitalize()}: {value["cantidad"]}")
            return 
        key, value not in nuevo_producto.items()
        print("El producto indicado no está en el inventario. Por favor, primero actualiza el inventario e inténtalo de nuevo")

# %%
def actualizar_stock(self, nombre, cantidad):
        for nuevo_producto in self.inventario:
            for key,value in nuevo_producto.items():
                if key["nombre"] == nombre and value["cantidad"] == cantidad:
                     self.inventario.update()
                     print("El stock ha sido actualizado")
                else:
                     print("El producto indicado no está en el inventario. Por favor, primero actualiza el inventario e inténtalo de nuevo")
